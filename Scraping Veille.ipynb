# %%
#importing required Libraries
import pandas as pd   
import requests       
from bs4 import BeautifulSoup 
import numpy as np

# %%
#assigning the URL with variable name url
url = 'https://www.imdb.com/search/title/?count=100&groups=top_1000&sort=user_rating'
#request allow you to send HTTP request
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
#creating an empty list, so that we can append the values
movie_name = []
year = []
time = []
rating = []
metascore = []
votes = []
gross = []
description = []
Director = []

# %%
#storing the meaningfull required data in the variable
movie_data = soup.findAll('div', attrs= {'class': 'lister-item mode-advanced'})

# %%
for store in movie_data:
    name = store.h3.a.text
    movie_name.append(name)
    
    year_of_release = store.h3.find('span', class_ = 'lister-item-year text-muted unbold').text
    year.append(year_of_release)
    
    runtime = store.p.find('span', class_ = 'runtime').text
    time.append(runtime)
    
    rate = store.find('div', class_ = 'inline-block ratings-imdb-rating').text
    rating.append(rate)
    
    meta  = store.find('span', class_ = 'metascore').text.replace(' ', '') if store.find('span', class_ = 'metascore') else '^^^^^^'
    metascore.append(meta)
    #since, gross and votes have same attributes, that's why we had created a common variable and then used indexing
    value = store.find_all('span', attrs = {'name': 'nv'})
    
    vote = value[0].text
    votes.append(vote)
    
    grosses = value[1].text if len(value) >1 else '*****'
    gross.append(grosses)
    
     # Description of the Movies -- Not explained in the Video, But you will figure it out. 
    describe = store.find('p', class_ = 'text-muted').text
    description.append(describe)
    
    #Cast Details -- Scraping Director name and Stars -- Not explained in Video
    director=store.find('p',class_='').a.text
    Director.append(director)

# %%
 movie_name
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'Kantara',
#  'The Dark Knight',
#  'The Lord of the Rings: The Return of the King',
#  "Schindler's List",
#  'The Godfather Part II',
#  '12 Angry Men',
#  '777 Charlie',
#  'Jai Bhim',
#  'Pulp Fiction',
#  'Rocketry: The Nambi Effect',
#  'Inception',
#  'The Lord of the Rings: The Two Towers',
#  'Fight Club',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Forrest Gump',
#  'Il buono, il brutto, il cattivo',
#  'Soorarai Pottru',
#  'The Matrix',
#  'Goodfellas',
#  'The Empire Strikes Back',
#  "One Flew Over the Cuckoo's Nest",
#  'Sita Ramam',
#  'Interstellar',
#  'Cidade de Deus',
#  'Sen to Chihiro no kamikakushi',
#  'Saving Private Ryan',
#  'The Green Mile',
#  'La vita è bella',
#  'Se7en',
#  'Terminator 2: Judgment Day',
#  'The Silence of the Lambs',
#  'Star Wars',
#  'Seppuku',
#  'Shichinin no samurai',
#  "It's a Wonderful Life",
#  'Kaithi',
#  '96',
#  'Gisaengchung',
#  'Whiplash',
# ...

# %%
np.count_nonzero(movie_name)
# Out:
# 100

# %%
 year
# Out:
# ['(1994)',
#  '(1972)',
#  '(2022)',
#  '(2008)',
#  '(2003)',
#  '(1993)',
#  '(1974)',
#  '(1957)',
#  '(2022)',
#  '(2021)',
#  '(1994)',
#  '(2022)',
#  '(2010)',
#  '(2002)',
#  '(1999)',
#  '(2001)',
#  '(1994)',
#  '(1966)',
#  '(2020)',
#  '(1999)',
#  '(1990)',
#  '(1980)',
#  '(1975)',
#  '(2022)',
#  '(2014)',
#  '(2002)',
#  '(2001)',
#  '(1998)',
#  '(1999)',
#  '(1997)',
#  '(1995)',
#  '(1991)',
#  '(1991)',
#  '(1977)',
#  '(1962)',
#  '(1954)',
#  '(1946)',
#  '(2019)',
#  '(II) (2018)',
#  '(2019)',
#  '(2014)',
#  '(2011)',
#  '(2006)',
#  '(2006)',
#  '(2002)',
#  '(2000)',
#  '(1998)',
#  '(1995)',
#  '(1994)',
#  '(1994)',
#  '(1988)',
#  '(1988)',
#  '(1985)',
#  '(1979)',
#  '(1979)',
#  '(1968)',
#  '(1960)',
#  '(1954)',
#  '(1942)',
#  '(1936)',
#  '(1931)',
#  '(2019)',
#  '(2022)',
#  '(2020)',
#  '(2018)',
#  '(I) (2019)',
#  '(2016)',
#  '(2018)',
#  '(2019)',
#  '(2018)',
#  '(I) (2017)',
#  '(2012)',
#  '(2022)',
#  '(2012)',
#  '(2021)',
# ...

# %%
np.count_nonzero(year)
# Out:
# 100

# %%
time
# Out:
# ['142 min',
#  '175 min',
#  '148 min',
#  '152 min',
#  '201 min',
#  '195 min',
#  '202 min',
#  '96 min',
#  '164 min',
#  '164 min',
#  '154 min',
#  '157 min',
#  '148 min',
#  '179 min',
#  '139 min',
#  '178 min',
#  '142 min',
#  '161 min',
#  '153 min',
#  '136 min',
#  '145 min',
#  '124 min',
#  '133 min',
#  '163 min',
#  '169 min',
#  '130 min',
#  '125 min',
#  '169 min',
#  '189 min',
#  '116 min',
#  '127 min',
#  '137 min',
#  '118 min',
#  '121 min',
#  '133 min',
#  '207 min',
#  '130 min',
#  '145 min',
#  '158 min',
#  '132 min',
#  '106 min',
#  '112 min',
#  '130 min',
#  '151 min',
#  '150 min',
#  '155 min',
#  '119 min',
#  '106 min',
#  '110 min',
#  '88 min',
#  '155 min',
#  '89 min',
#  '116 min',
#  '147 min',
#  '117 min',
#  '165 min',
#  '109 min',
#  '112 min',
#  '102 min',
#  '87 min',
#  '87 min',
#  '141 min',
#  '175 min',
#  '160 min',
#  '126 min',
#  '122 min',
#  '106 min',
#  '117 min',
#  '181 min',
#  '149 min',
#  '105 min',
# ...

# %%
np.count_nonzero(time)
# Out:
# 100

# %%
rating
# Out:
# ['\n\n9.3\n',
#  '\n\n9.2\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n9.0\n',
#  '\n\n8.9\n',
#  '\n\n8.9\n',
#  '\n\n8.9\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.8\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.7\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.6\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.5\n',
#  '\n\n8.4\n',
# ...

# %%
np.count_nonzero(rating)
# Out:
# 100

# %%
metascore
# Out:
# ['81',
#  '100',
#  '^^^^^^',
#  '84',
#  '94',
#  '94',
#  '90',
#  '96',
#  '^^^^^^',
#  '^^^^^^',
#  '94',
#  '^^^^^^',
#  '74',
#  '87',
#  '66',
#  '92',
#  '82',
#  '90',
#  '^^^^^^',
#  '73',
#  '90',
#  '82',
#  '84',
#  '^^^^^^',
#  '74',
#  '79',
#  '96',
#  '91',
#  '61',
#  '59',
#  '65',
#  '75',
#  '85',
#  '90',
#  '85',
#  '98',
#  '89',
#  '^^^^^^',
#  '^^^^^^',
#  '96',
#  '89',
#  '57',
#  '66',
#  '85',
#  '85',
#  '67',
#  '62',
#  '77',
#  '64',
#  '88',
#  '80',
#  '94',
#  '87',
#  '94',
#  '89',
#  '80',
#  '97',
#  '100',
#  '100',
#  '96',
#  '99',
#  '^^^^^^',
#  '^^^^^^',
#  '90',
#  '75',
#  '59',
#  '79',
#  '87',
#  '78',
#  '68',
#  '81',
#  '81',
#  '78',
#  '78',
#  '^^^^^^',
#  '67',
#  '^^^^^^',
#  '^^^^^^',
#  '^^^^^^',
#  '95',
#  '89',
#  '77',
#  '80',
#  '84',
#  '76',
#  '68',
#  '^^^^^^',
#  '84',
#  '88',
#  '85',
#  '86',
#  '66',
#  '90',
#  '97',
#  '76',
#  '90',
#  '^^^^^^',
#  '^^^^^^',
#  '^^^^^^',
#  '^^^^^^']

# %%
np.count_nonzero(metascore)
# Out:
# 100

# %%
votes
# Out:
# ['2,663,839',
#  '1,846,006',
#  '68,298',
#  '2,636,794',
#  '1,836,566',
#  '1,348,926',
#  '1,264,427',
#  '786,660',
#  '30,369',
#  '201,217',
#  '2,038,950',
#  '49,524',
#  '2,336,556',
#  '1,658,355',
#  '2,109,222',
#  '1,865,634',
#  '2,064,619',
#  '759,213',
#  '116,563',
#  '1,903,340',
#  '1,154,470',
#  '1,286,422',
#  '1,004,582',
#  '45,064',
#  '1,810,389',
#  '754,935',
#  '759,015',
#  '1,384,514',
#  '1,294,435',
#  '692,616',
#  '1,641,936',
#  '1,094,539',
#  '1,425,233',
#  '1,358,985',
#  '57,289',
#  '345,694',
#  '454,464',
#  '32,373',
#  '31,511',
#  '792,568',
#  '852,551',
#  '854,272',
#  '1,326,882',
#  '1,319,050',
#  '828,313',
#  '1,492,812',
#  '1,118,902',
#  '1,081,829',
#  '1,155,877',
#  '1,053,270',
#  '261,054',
#  '276,809',
#  '1,198,222',
#  '665,880',
#  '879,341',
#  '329,250',
#  '670,388',
#  '491,144',
#  '570,655',
#  '242,633',
#  '185,051',
#  '29,677',
#  '57,007',
#  '94,277',
#  '89,768',
#  '1,267,977',
#  '267,129',
# ...

# %%
np.count_nonzero(votes)
# Out:
# 100

# %%
gross
# Out:
# ['$28.34M',
#  '$134.97M',
#  '*****',
#  '$534.86M',
#  '$377.85M',
#  '$96.90M',
#  '$57.30M',
#  '$4.36M',
#  '*****',
#  '#236',
#  '$107.93M',
#  '*****',
#  '$292.58M',
#  '$342.55M',
#  '$37.03M',
#  '$315.54M',
#  '$330.25M',
#  '$6.10M',
#  '*****',
#  '$171.48M',
#  '$46.84M',
#  '$290.48M',
#  '$112.00M',
#  '*****',
#  '$188.02M',
#  '$7.56M',
#  '$10.06M',
#  '$216.54M',
#  '$136.80M',
#  '$57.60M',
#  '$100.13M',
#  '$204.84M',
#  '$130.74M',
#  '$322.74M',
#  '#44',
#  '$0.27M',
#  '#21',
#  '*****',
#  '*****',
#  '$53.37M',
#  '$13.09M',
#  '$13.18M',
#  '$53.09M',
#  '$132.38M',
#  '$32.57M',
#  '$187.71M',
#  '$6.72M',
#  '$23.34M',
#  '$19.50M',
#  '$422.78M',
#  '$11.99M',
#  '#46',
#  '$210.61M',
#  '$83.47M',
#  '$78.90M',
#  '$5.32M',
#  '$32.00M',
#  '$36.76M',
#  '$1.02M',
#  '$0.16M',
#  '$0.02M',
#  '*****',
#  '*****',
#  '#108',
#  '$1.66M',
#  '$335.45M',
#  '$5.02M',
#  '$190.24M',
#  '$858.37M',
#  '$678.82M',
#  '$209.73M',
#  '$162.81M',
#  '#82',
# ...

# %%
np.count_nonzero(gross)
# Out:
# 100

# %%
description
# Out:
# ['\nR\n|\n142 min\n|\n\nDrama            \n',
#  '\n175 min\n|\n\nCrime, Drama            \n',
#  '\n148 min\n|\n\nAction, Adventure, Drama            \n',
#  '\nPG-13\n|\n152 min\n|\n\nAction, Crime, Drama            \n',
#  '\nPG-13\n|\n201 min\n|\n\nAction, Adventure, Drama            \n',
#  '\nR\n|\n195 min\n|\n\nBiography, Drama, History            \n',
#  '\n202 min\n|\n\nCrime, Drama            \n',
#  '\n96 min\n|\n\nCrime, Drama            \n',
#  '\n164 min\n|\n\nAdventure, Comedy, Drama            \n',
#  '\n164 min\n|\n\nCrime, Drama, Mystery            \n',
#  '\nR\n|\n154 min\n|\n\nCrime, Drama            \n',
#  '\n157 min\n|\n\nBiography, Drama            \n',
#  '\nPG-13\n|\n148 min\n|\n\nAction, Adventure, Sci-Fi            \n',
#  '\nPG-13\n|\n179 min\n|\n\nAction, Adventure, Drama            \n',
#  '\nR\n|\n139 min\n|\n\nDrama            \n',
#  '\nPG-13\n|\n178 min\n|\n\nAction, Adventure, Drama            \n',
# ...

# %%
np.count_nonzero(description)
# Out:
# 100

# %%
Director
# Out:
# ['Frank Darabont',
#  'Francis Ford Coppola',
#  'Rishab Shetty',
#  'Christopher Nolan',
#  'Peter Jackson',
#  'Steven Spielberg',
#  'Francis Ford Coppola',
#  'Sidney Lumet',
#  'Kiranraj K',
#  'T.J. Gnanavel',
#  'Quentin Tarantino',
#  'Madhavan',
#  'Christopher Nolan',
#  'Peter Jackson',
#  'David Fincher',
#  'Peter Jackson',
#  'Robert Zemeckis',
#  'Sergio Leone',
#  'Sudha Kongara',
#  'Lana Wachowski',
#  'Martin Scorsese',
#  'Irvin Kershner',
#  'Milos Forman',
#  'Hanu Raghavapudi',
#  'Christopher Nolan',
#  'Fernando Meirelles',
#  'Hayao Miyazaki',
#  'Steven Spielberg',
#  'Frank Darabont',
#  'Roberto Benigni',
#  'David Fincher',
#  'James Cameron',
#  'Jonathan Demme',
#  'George Lucas',
#  'Masaki Kobayashi',
#  'Akira Kurosawa',
#  'Frank Capra',
#  'Lokesh Kanagaraj',
#  'C. Prem Kumar',
#  'Bong Joon Ho',
#  'Damien Chazelle',
#  'Olivier Nakache',
#  'Christopher Nolan',
#  'Martin Scorsese',
#  'Roman Polanski',
#  'Ridley Scott',
#  'Tony Kaye',
# ...

# %%
np.count_nonzero(Director)
# Out:
# 100

# %%
#creating a dataframe using pandas library
movie_DF = pd.DataFrame({'Name of movie': movie_name, 'Year of relase': year, 'Watchtime': time, 'Movie Rating': rating, 'Metascore': metascore, 'Votes':votes, 'grosses':gross, 'discription':description})

# %%
movie_DF
# Out:
#                                     Name of movie Year of relase Watchtime  \
# 0                        The Shawshank Redemption         (1994)   142 min
# 1                                   The Godfather         (1972)   175 min
# 2                                         Kantara         (2022)   148 min
# 3                                 The Dark Knight         (2008)   152 min
# 4   The Lord of the Rings: The Return of the King         (2003)   201 min
# ..                                            ...            ...       ...
# 95                                 Paths of Glory         (1957)    88 min
# 96                                   Sunset Blvd.         (1950)   110 min
# 97                             The Great Dictator         (1940)   125 min
# 98                                     Chhichhore         (2019)   143 min
# 99                                       Ratsasan         (2018)   170 min
#
#    Movie Rating Metascore      Votes   grosses  \
# ...

# %%
movie_DF.to_excel("Top_100_IMDB_Movies.xlsx")
